# %% [markdown]
# ### Oefenvragen voor deel 3: Modules en functies
#
# Hieronder een lijst oefenvragen behorende bij deel 3 van deze Python cursus. Informatie voor de antwoorden op deze vragen staat niet altijd in deze handleiding zelf, en zul je deels op internet moeten opzoeken. Effectief informatie zoeken voor Python is een belangrijk onderdeel van het leren van Python. Als je hierna nog meer wilt oefenen dan raden wij je aan om samen met je buurman of buurvrouw vragen te gaan maken die je vervolgens door de ander op laat lossen.

# %% [markdown]
# **Welke modules en welke functies kun je gebruiken om de volgende vragen op te lossen?**

# %% [markdown]
# Vraag 1. De standaard deviatie van de volgende reeks getallen:

# %%
reeks_getallen = [10.2, 2.6, 10.5, 5.0, 20.9]

# %% [markdown]
# Vraag 2. Het minimum van de volgende reeks getallen:

# %%
reeks_getallen = [10.2, 2.6, 10.5, 5.0, 20.9]

# %% [markdown]
# Vraag 3. De kleinste waarde van de volgende reeks getallen:

# %%
reeks_getallen = [10.2, 2.6, -10.5, -5.0, 20.9]

# %% [markdown]
# Vraag 4. Print de volgende zin "De omtrek van de aarde is ..." waar je de puntjes moet vervangen door de een berekening van de omtrek van de Aarde.
# Tip: Gebruik hiervoor een module met constanten zoals de radius van de Aarde, en bereken dan de omtrek met: omtrek = 2$\pi$ radius

# %% [markdown]
# <!-- Links -->
# [python_antwoordenblad]: Python_answers.ipynb
#
# # Ga naar het antwoordenblad: [Python_antwoordenblad][python_antwoordenblad]

# %% [markdown]
# <!-- Links -->
# [python_modules]: 03_Python_modules_functies.ipynb
# [Python_ZelfFunctiesMaken]: 04_Python_zelf_functies_maken.ipynb
#
# # Ga naar het volgende deel: [04_Python_zelf_functies_maken][Python_ZelfFunctiesMaken]
#
# # Ga terug naar het vorige deel: [03_Python_modules_functies][python_modules]
